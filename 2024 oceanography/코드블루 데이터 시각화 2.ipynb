# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
#격자 생성
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
#1행 1열 첫번째

dat = [2,4,5,9]
ax.plot(dat)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
#격자 생성
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
#1행 1열 첫번째

#직접 x,y값 할당
x = [0,2,4,6,8]
y = [1,10,100,500,1000]
ax.plot(x,y)

plt.show()

# %%
#import os
#import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import random

data=pd.read_csv('/Users/wone/Downloads/seaice_extent_month_20240403.csv',index_col=0, encoding='utf-8-sig')
data.head()

plt.style.use('ggplot')
#격자 생성

fig = plt.figure(figsize=(25,8))
ax = fig.add_subplot(111)
#슬라이싱해서 8월 잘라내야함 
#앞에 뜨는 오류 jupyter에서 해결 불가능 
plt.rcParams['font.family'] = 'AppleGothic'

ax.plot(data.index, data['북극 해빙면적 평균(10^6km)'],color='slategrey',linewidth='6')
#ax.plot(data.index, data['year'])

ax.set_title('seaice extent')
ax.set_ylabel('extent')
ax.set_xlabel('years')

plt.show()
# Out:
# /Users/wone/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65279 (\N{ZERO WIDTH NO-BREAK SPACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
